# %% [markdown]
# #*ASSIGNMENT-1*

# %% [markdown]
# ###COLAB HACK
# MULTILINE SELECT : ALT+CLICK \
# CHOOSE ALL THE SAME ITEMS IN A CELL: CTRL + SHIFT +L

# %%
#TASK-                                                    #input 32,60 ans=28
# First, we take 2 numbers as input from the user
# Read 2 numbers as input from the user means taking 2 numbers as input from the user using
var_1 = input('Please enter the first number: ')
var_2 = input('Please enter the second number: ')
#Since input() function converts everything to String,
#for performing any kind of mathematical operation we need to convert them to int.
#For this conversion, we need to use the int() function
#But at first, we may clarify whether the inputs are actually Strings or not. 
#Then we convert the Strings to integer using the int() function
var_3 = int(var_1)
var_4 = int(var_2)
#===============================================================
#Input taking and conversion can be done in a single line as shown below
#var_1 = int(input('Please enter the first number: '))
#var_2 = int(input('Please enter the second number: '))
#===============================================================
#We may then perform Addition
total = var_3 + var_4
#Multiplication 
product = var_3 * var_4
#Substraction 
difference = var_3 - var_4
#And then print all the calculated results
print("Sum =", total)
print("Product =", product)
print("Difference =", difference)
# Out:
# Please enter the first number: 4
# Please enter the second number: 5
# Sum = 9
# Product = 20
# Difference = -1

# %%
#TASK-2                                                    #input 3.5
import math
# taking input from the user, then converting it to float
# since radius can be a floating point value
radius = float(input("Please enter the radius value:")) 
# squares can be made using these 3 ways, as give in hints
# all 3 ways generates the same result for area

#++++++++++++++++You can do it in three ways that is done below ##########
area = math.pi * radius ** 2
print("Area is:", area)
area = math.pi * math.pow(radius, 2)
print("Area is:", area)
area = math.pi * radius * radius
print("Area is:", area)
#==============================================================
# calculate circumference
circumference=2*math.pi*radius
print("Circumference is:", circumference)
#==============================================================
# Out:
# Please enter the radius value:3.5
# Area is: 38.48451000647496
# Area is: 38.48451000647496
# Area is: 38.48451000647496
# Circumference is: 21.991148575128552

# %%
#TASK-3                                                                   #input 7,3
num_one=int(input("Enter the first number:"))
num_two=int(input("Enter the second number:"))
if ( num_one>num_two ):
 print("First is Greater")
elif( num_two>num_one ):
 print("Second is Greater")
else:
 print("The numbers are Equal")
# Out:
# Enter the first number:7
# Enter the second number:3
# First is Greater

# %%
#TASK-4                                                                   #input -40,-4
num_one=int(input("Enter the first number:"))
num_two=int(input("Enter the second number:"))
if ( num_one>num_two ):
 print(num_one-num_two)
elif( num_two>num_one ):
 print(num_two-num_one)
 
else:
 print(0)
# Out:
# Enter the first number:5
# Enter the second number:5
# 0

# %%
#TASK-5                                                                  #input -44
num_one=int(input("Enter a number:"))
if (num_one%2==0):
 print("The number is even")
else:
 print("The number is odd")
# Out:
# Enter a number:-44
# The number is even

# %%
#TASK-6                                                                   #input 5 or 10
num_one=int(input("Enter a number:"))
if (num_one%2==0 or num_one%5==0):
 print(num_one)
 
else:
 print("Not a multiple of 2 Or 5")
# Out:
# Enter a number:1
# Not a multiple of 2 Or 5

# %%
#TASK-7                                                                   #input 5,69
num=int(input("Enter a number:"))
if(num%2==0 and num%5!=0):
 print(num)
 
elif (num%5==0 and num%2!=0):
 print(num)
 
elif (num%2==0 and num%5==0):
 print("Multiple of 2 and 5 both")
 
else:
 print("Not a multiple we want")
# Out:
# Enter a number:69
# Not a multiple we want

# %%
#TASK-8                                                                   #input 30,69
num=int(input("Enter a number:"))
if (num%2==0 and num%5==0):
 print(num)
 
else:
 print("Not multiple of 2 and 5 both")
# Out:
# Enter a number:69
# Not multiple of 2 and 5 both

# %%
#TASK-9                                                                   #input 10000
sec=int(input("Enter the number of seconds:"))
hours=sec//3600
left_seconds=sec%3600
minute=left_seconds//60
second=left_seconds%60
#pinting all together to match the sample output
print("Hours:", hours, "Minute:", minute, "Second:", second)
# Out:
# Enter the number of seconds:500
# Hours: 0 Minute: 8 Second: 20

# %%
#TASK-10                                                                   #input 170
worktime=int(input("Enter the number of working hours:"))
if (worktime<0 ):
 print("Hour cannot be negative")
 
elif(worktime>168):
 print("Impossible to work more than 168 hours weekly")
 
elif(worktime<=40):
 print(worktime*200)
 
elif(worktime>40):
 print(8000+((worktime-40)*300))
# Out:
# Enter the number of working hours:100
# 26000

# %%
#TASK-11                                                                   #input 3
value_s=int(input("Enter the value of S:"))
if (value_s < 100):
 print(3000-125*value_s*value_s)
 
elif (value_s >=100):
 print(12000/(4+(value_s*value_s)/14900))
# Out:
# Enter the value of S:3
# 1875

# %%
#TASK-12                                                                   #input  4,5,6,25
time=int(input("Pease input the time:"))
if( time<0 or time>23):
   print("Wrong time")
 
if(time>=0 and time<=23):
   if(time>=4 and time<=6):
       print("Breakfast")
     
   elif(time>=12 and time<=13):
       print("Lunch")
     
   elif(time>=16 and time<=17):
       print("Snacks")
     
   elif(time>=19 and time<=20):
       print("Dinner") 
     
   else:
       print("Patience is a virtue")
# Out:
# Pease input the time:25
# Wrong time

# %%
#TASK-13                                                                   #input 60,70,80,95,120
mark=int(input("Enter your mark:"))
#for invalid input part
if ( mark>100 ):
   print("Invalid input")
elif ( mark<0 ):
   print("Invalid input")
 
#for fail marks
elif (mark>=0 and mark <50):
   print("F")
 
#for the rest grading
elif mark>=50 and mark<=59 :
   print("E")
elif (mark>=60 and mark<=69):
   print("D")
elif (mark>=70 and mark<=79):
   print("C")
elif (mark>=80 and mark<=89):
   print("B")
elif (mark>=90 and mark<=100):
   print("A OREEE-CG 4.00")
# Out:
# Enter your mark:95
# A OREEE-CG-4

# %%
#TASK-14                                                                   #input 77+
temp_a=int(input("Enter the temperature:"))
#conversion
temp=((temp_a-32)*0.56)
#degreesC is added to match the sample output
print(round(temp),"degrees C")
#condition part 
if (temp<20):
 print("Winter")
elif (temp>=20 and temp<25):
 print("Autumn")
elif (temp>=25 and temp<=29):
 print("Spring")
elif( temp>=30):
 print("Summer")
# Out:
# Enter the temperature:67
# 20 degrees C
# Winter

# %%
#TASK-15                                                                  #input 160000,7200
distance_a=int(input("Enter the distance in meters:"))
time_a=int(input("Enter the time in seconds:"))
#calculation part
velocity=((distance_a/time_a)*3.6)
print(velocity, "km/h")
#condition part 
if ( velocity<60 ):
 print("Too slow. Needs more changes.")
 
elif ( velocity>=60 and velocity<=90 ):
 print("Velocity is okay. The car is ready!")
 
elif (velocity>90 ):
 print("Too fast. Only a few changes should suffice")
# Out:
# Enter the distance in meters:160000
# Enter the time in seconds:7200
# 80.0 km/h
# Velocity is okay. The car is ready!

# %%
#TASK-16                                #input
#Cg mark input 
cgpa=float(input("Enter your CGPA:"))
credit=int(input("Enter your no. of Credit"))
#condition part 
if( credit<30 or cgpa< 3.80):
   print("The students is not eligible for a waiver") 
if( credit>=30 and cgpa>=3.80):
    if(cgpa>=3.80 and cgpa<=3.89):
        print("The student is eligible for a waiver of 25 percent")
    elif(cgpa>=3.90 and cgpa<=3.94):
        print("The student is eligible for a waiver of 50 percent")
    elif(cgpa>=3.95 and cgpa<=3.99):
        print("The student is eligible for a waiver of 75 percent")
    elif(cgpa==4.00):
        print("The student is eligible for a waiver of 100 percent")
    else:
        print("Invalid Input")
# Out:
# Enter your CGPA:4
# Enter your no. of Credit29
# The students is not eligible for a waiver
