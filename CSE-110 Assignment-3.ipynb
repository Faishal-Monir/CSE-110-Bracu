# %% [markdown]
# #*ASSIGNMENT-3*

# %%
#TASK-1                                #input 22101265
data=input("Enter data:")
print(data[-1::-1])
# Out:
# Enter data:22101295
# 59210122

# %%
#TASK- 1                                #input BRACVSNSU
data=input("Enter your data:")
index_value=int(input("Enter index value:"))
reverse_part=data[index_value::-1]
rest=data[index_value+1::]
print(reverse_part+rest)
# Out:
# Enter your data:BRACVSNSU
# Enter index value:5
# SVCARBNSU

# %%
#TASK-3                                #input 1020, 00111100
data=input("Enter your number:")
binary=True
for x in data:
    if x=="0" or x=="1" :
        pass
    else:
        binary=False
        break
 
if binary==True:
 print("Binary Number")
else:
 print("Not a Binary Number")
# Out:
# Enter your number:00111100
# Binary Number

# %%
#TASK-4                               #input ber
data=input("Enter a word:")
if data.endswith("er") :
    print(data.replace("er","est"))
elif data.endswith("est"):
    print(data)
 
elif len(data)<4 :
    print(data)
 
else:
    print(data+"er")
# Out:
# Enter a word:ber
# best

# %%
#TASK-5                                #input MURGIRFARM
data=input("Enter a word:")
lenght=len(data)
for index in range(0,lenght+1):
    print(data[:index:])
# Out:
# Enter a word:MURGIRFARM
#
# M
# MU
# MUR
# MURG
# MURGI
# MURGIR
# MURGIRF
# MURGIRFA
# MURGIRFAR
# MURGIRFARM

# %%
#TASK-6                              #input MurgirFarm
data=input("Enter a word:")
for index in data:
    print(f"{index}:{ord(index)}")
# Out:
# Enter a word:MurgirFarm
# M:77
# u:117
# r:114
# g:103
# i:105
# r:114
# F:70
# a:97
# r:114
# m:109

# %%
#TASK-7                                #input xyzabc
data=input("Enter data:")
small=data.lower()
output=""
for letters in small:
 
    if letters=="z":
        store="a"
        output=output+store
    else:
        store=chr(ord(letters)+1)
        output=output+store
 
print(output,end="")
# Out:
# Enter data:xyzABC
# yzabcd

# %%
#TASK-8                              #input nsubest
data=input("Enter data:")
string=data[1::2]
for capital in string:
    result=chr(ord(capital)-32)
    print(result,end="")
# Out:
# Enter data:nsubest
# SBS

# %%
#TASK-9                                #input BRAC@SHOPPINGMALL
data=input("Enter data:")
bhag=input("Enter splitting character:")
for update in data:
    if update!= bhag:
        print(update,end="")
    else:
        print()
# Out:
# Enter data:BRAC@SHOPPINGMALL
# Enter splitting character:@
# BRAC
# SHOPPINGMALL

# %%
#TASK-10                                #input AAaaaAaaAAAa
data=input("Enter your data:")
current_character=""
new_character=""
for duplicates in data:
    if current_character!= duplicates:
        current_character=duplicates
        new_character=(new_character+duplicates)
 
print(new_character)
# Out:
# Enter your data:AAaaaAaaAAAa
# AaAaAa

# %%
#TASK-11                                #input BRACU IS THE BEST UNIVERSITY IN THE WORLD
# i used lower input formula so if you enter a capital letter it will turn small evantually
#______________________input section_____________________________
data=input("Enter string data:")
data_letter=input("Enter the letter:")
small_a=data_letter.lower()
small=data.lower()
y=len(data)
counter=""
#__________________Processing codes______________________________
if data_letter in data:
    counter=(data.replace(data_letter,""))
 
elif y>3:
    counter=data[1:-1:]
else:
    counter=data
print(counter)
# Out:
# Enter string data:BRACU IS THE BEST UNIVERSITY IN THE WORLD
# Enter the letter:B
# RACU IS THE EST UNIVERSITY IN THE WORLD

# %%
#TASK-12                                #input :    abcd,efgh
data=input("Enter string:")
#+++++++++++++++++++Separation done++++++++++++++++++++++++++++++
first_part=""
second_part=""
final=""
for index in range(len(data)):
    if (data[index] !="," ):
        first_part=first_part+data[index]
    else:
        second_part=data[index+1:]
        break
#+++++++++++++++++Process code++++++++++++++++++++++++++++++++++
 
if len(first_part)>len(second_part):
 
    for index in range(len(second_part)):
        final=final+first_part[index] 
        final=final+second_part[index] 
    final=final+first_part[len(second_part):]

elif len(first_part)<len(second_part):
    for index in range(len(first_part)):
        final=final+first_part[index]
        final=final+second_part[index]
     
 
    final=final+second_part[len(first_part):]
 
else:
    for index in range(len(first_part)):
 
        final+=first_part[index]
 
        final+=second_part[index]
 
print(final)
# Out:
# Enter string:abcd,efgh
# aebfcgdh
